# %%
from gratin.standard import train_model

# %%
train_model(
    export_path= "/Users/hverdier/models/demo",
    #export_path="/home/hverdier/models/demo_standard",
    num_workers=2,
    time_delta=.03)
# Out:
# stage is None, strange...
# Create TrajDataset, seed_offset = 100000
# Create TrajDataset, seed_offset = 0
# Create TrajDataset, seed_offset = 200000
# Create TrajDataset, seed_offset = 100000
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/callbacks/model_checkpoint.py:608: UserWarning: Checkpoint directory /Users/hverdier/models/demo exists and is not empty.
#   rank_zero_warn(f"Checkpoint directory {dirpath} exists and is not empty.")
# Sanity Checking: 0it [00:00, ?it/s]
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, val_dataloader 0, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Create TrajDataset, seed_offset = 200000
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/trainer/connectors/data_connector.py:240: PossibleUserWarning: The dataloader, train_dataloader, does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` (try 8 which is the number of cpus on this machine) in the `DataLoader` init to improve performance.
#   rank_zero_warn(
# Training: 0it [00:00, ?it/s]
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2116. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2265. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2075. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2105. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2092. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2002. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2148. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2267. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2226. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2204. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2145. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2229. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2262. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2124. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2374. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2005. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2234. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2166. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2320. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2183. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2279. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1947. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2276. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2168. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2051. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2044. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2275. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2227. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2155. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2170. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2126. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2260. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2246. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2162. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2180. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2190. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2083. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2144. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2123. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2261. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2120. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2101. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2076. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2163. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2346. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2238. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2172. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2247. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2079. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2098. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2022. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1956. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1921. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2299. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2259. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2033. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2095. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2342. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2090. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2202. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2318. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2287. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2087. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2141. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2217. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2216. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2003. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2169. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2127. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2185. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2134. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2338. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2046. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2040. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2208. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2273. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2157. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2292. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2213. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2084. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2150. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2069. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2277. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2059. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2231. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2156. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2167. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2043. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2112. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2258. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2233. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2093. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2139. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2068. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2244. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2357. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2196. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2094. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2020. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2237. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2154. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1973. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2251. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2264. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2211. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2137. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2034. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2324. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2254. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1990. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2135. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2294. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2301. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2189. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2288. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2147. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2161. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2113. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2293. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2151. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2199. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2230. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2114. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2029. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2117. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2174. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2269. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2194. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2136. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2256. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2223. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2130. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2176. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2153. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2140. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2207. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2182. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1996. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2186. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1958. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2119. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2193. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2314. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2104. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2107. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2164. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2070. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# ...
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2304. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2181. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2030. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2049. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2077. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2285. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2215. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2198. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2053. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2240. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2191. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2333. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2291. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2383. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2023. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2024. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2331. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1941. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2097. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2052. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2074. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2253. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2241. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2212. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2014. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1922. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2017. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2102. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2056. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2327. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1848. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2132. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1971. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2319. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2173. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2310. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2222. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2329. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2228. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2278. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2337. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2108. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2300. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2138. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2280. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2344. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2236. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# Validation: 0it [00:00, ?it/s]
# Create TrajDataset, seed_offset = 300000
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2330. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 1963. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
# /Users/hverdier/opt/miniconda3/envs/gratin/lib/python3.8/site-packages/pytorch_lightning/utilities/data.py:72: UserWarning: Trying to infer the `batch_size` from an ambiguous collection. The batch size we found is 2286. To avoid any miscalculations, use `self.log(..., batch_size=batch_size)`.
#   warning_cache.warn(
