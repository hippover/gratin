# %%
from gratin.standard import train_model

# %%
train_model(
    export_path="/Users/hverdier/models/demo_standard",
    time_delta=0.03)
# Out:
# Global seed set to 1
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Missing logger folder: /Users/hverdier/models/demo_standard/tb_logs/model
#
#   | Name           | Type              | Params
# -----------------------------------------------------
# 0 | encoder        | TrajsEncoder2     | 44.0 K
# 1 | features_maker | TrajsFeatures     | 0
# 2 | out_networks   | ModuleDict        | 29.9 K
# 3 | MAE            | MeanAbsoluteError | 0
# 4 | F1             | F1Score           | 0
# -----------------------------------------------------
# 74.0 K    Trainable params
# 0         Non-trainable params
# 74.0 K    Total params
# 0.296     Total estimated model params size (MB)
# stage is None, strange...
# Create TrajDataset, seed_offset = 0
# Create TrajDataset, seed_offset = 100000
# Create TrajDataset, seed_offset = 0
# Sanity Checking: 0it [00:00, ?it/s]
# ...
